# %% [markdown]
# <a href="https://colab.research.google.com/github/ElenaVillano/visualizacionR/blob/main/notebooks/s4_prettty_graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller visualización de datos: Sesión 2
#
# ### By Elena Villalobos Nolasco
#
# El día de hoy crearás tus propios gráficos...

# %%
#install.packages("ggsci")
#install.packages('ggridges')

# %%
library(tidyverse)
library(ggsci)
library(ggridges)

# %%
# Subir archivo
indicadores <- read_csv('sample_data/practica.csv')
# Out:
# Rows: 78 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): pais
# dbl (7): año, indic_1, indic_6, indic_2, indic_4, indic_3, indic_5
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
dim(indicadores)
# Out:
# [1] 78  8

# %%
head(indicadores)
# Out:
#   pais  año  indic_1 indic_6 indic_2 indic_4 indic_3 indic_5
# 1 Chile 2010 10.50   1.16    77.2    69.0    0.742   1.10
# 2 Chile 2011 29.00   1.15    77.4    67.0    0.742   1.07
# 3 Chile 2012    NA   1.18    78.3    72.0    0.742   1.08
# 4 Chile 2013 73.76   1.16    79.0    72.0    0.742   1.11
# 5 Chile 2014 74.20   1.04    78.7    72.3    0.783   1.06
# 6 Chile 2015 77.00   0.92    78.5    71.0    0.807   1.00

# %%
# Línea para hacer más grandes o pequeños los gráficos
options(repr.plot.with = 1, repr.plot.height = 5, repr.plot.res=250)

# %% [markdown]
# [<img src="https://datavizcatalogue.com/ES/metodos/images/anatomy/SVG/diagrama_cajas_y_bigotes.svg" width="400"/>]()

# %%
ggplot(data = indicadores, aes(x = pais, y = indic_1, color = pais)) +
  geom_boxplot()
# Out:
# Warning message:
# “Removed 6 rows containing non-finite values (`stat_boxplot()`).”
# plot without title

# %% [markdown]
# ## Temas en ggplot
#
#   - theme_gray(): signature ggplot2 theme
#   - theme_bw(): dark on light ggplot2 theme
#   - theme_linedraw(): uses black lines on white backgrounds only
#   - theme_light(): similar to linedraw() but with grey lines as well
#   - theme_dark(): lines on a dark background instead of light
#   - theme_minimal(): no background annotations, minimal feel
#   - theme_classic(): theme with no grid lines
#   - theme_void(): empty theme with no elements

# %%
ggplot(data = indicadores, aes(x = pais, y = indic_1, color = pais)) +
  geom_boxplot() #
  #theme_bw() +
  #theme_classic() +
  #theme_light() +
  theme_minimal() +
  #geom_boxplot(na.rm=TRUE) +
  #theme(legend.position = "none")
#
